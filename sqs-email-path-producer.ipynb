# %%
# !pip install boto3
# Out:
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.11/site-packages (1.36.3)
# Requirement already satisfied: botocore<1.37.0,>=1.36.3 in /opt/conda/lib/python3.11/site-packages (from boto3) (1.36.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /opt/conda/lib/python3.11/site-packages (from boto3) (0.11.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore<1.37.0,>=1.36.3->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore<1.37.0,>=1.36.3->boto3) (1.26.19)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.37.0,>=1.36.3->boto3) (1.17.0)

# %%
import boto3
import re

# AWS Region
AWS_REGION = "us-east-1"

# Initialize AWS Clients
s3 = boto3.client("s3", region_name=AWS_REGION)
sns = boto3.client("sns", region_name=AWS_REGION)

# ✅ Hardcoded SNS Topic Name
SNS_TOPIC_NAME = "email-path-distribution-topic"

# %%
# ✅ Input: Full S3 URL
S3_URL = "s3://email-sec-datasets-bronze/email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/"

# %%
# ✅ Function to Extract Bucket Name & Prefix from S3 URL
def parse_s3_url(s3_url):
    """Extracts bucket name and prefix from an S3 URL."""
    match = re.match(r"s3://([^/]+)/(.+)", s3_url)
    if match:
        return match.group(1), match.group(2)
    return None, None

# ✅ List All File Paths in S3 Directory
def list_s3_files(bucket_name, prefix):
    """Lists all files inside the given S3 directory (prefix)."""
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)
    files = [obj["Key"] for obj in response.get("Contents", [])] if "Contents" in response else []
    
    if not files:
        print("⚠️ No files found in the directory.")
    else:
        print(f"✅ Found {len(files)} files in '{prefix}':\n")
        for file in files[:10]:  # Display only first 10 files for brevity
            print(f"- {file} (and more...)")
    
    return files

# ✅ Fetch SNS Topic ARN by Name
def get_sns_topic_arn(topic_name):
    """Fetch SNS Topic ARN by topic name."""
    response = sns.list_topics()
    for topic in response.get("Topics", []):
        if topic_name in topic["TopicArn"]:
            return topic["TopicArn"]
    return None

# ✅ Publish File Paths to SNS
def publish_to_sns(topic_arn, file_path):
    """Publishes file path to SNS topic."""
    try:
        sns.publish(TopicArn=topic_arn, Message=file_path)
        print(f"✅ Sent to SNS: {file_path}")
    except Exception as e:
        print(f"❌ Failed to send {file_path} to SNS: {str(e)}")

# ✅ Extract Bucket & Prefix
S3_BUCKET_NAME, DIRECTORY_PREFIX = parse_s3_url(S3_URL)

if not S3_BUCKET_NAME or not DIRECTORY_PREFIX:
    print("❌ Invalid S3 URL. Please enter a valid S3 URL.")
else:
    print(f"✅ Extracted S3 Bucket: {S3_BUCKET_NAME}")
    print(f"✅ Extracted S3 Directory Prefix: {DIRECTORY_PREFIX}")

    # ✅ Fetch SNS Topic ARN
    SNS_TOPIC_ARN = get_sns_topic_arn(SNS_TOPIC_NAME)

    if not SNS_TOPIC_ARN:
        print(f"❌ SNS Topic '{SNS_TOPIC_NAME}' not found in {AWS_REGION}.")
    else:
        print(f"✅ Fetched SNS Topic ARN: {SNS_TOPIC_ARN}")

        # ✅ List Files in S3 Directory
        file_paths = list_s3_files(S3_BUCKET_NAME, DIRECTORY_PREFIX)

        # ✅ Publish Each File Path to SNS
        for file_path in file_paths:
            publish_to_sns(SNS_TOPIC_ARN, file_path)
# Out:
# ✅ Extracted S3 Bucket: email-sec-datasets-bronze
# ✅ Extracted S3 Directory Prefix: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/
# ✅ Fetched SNS Topic ARN: arn:aws:sns:us-east-1:221082192243:email-path-distribution-topic
# ✅ Found 66 files in 'email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/':
#
# - email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/1. (and more...)
# - email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/10. (and more...)
# - email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/11. (and more...)
# - email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/12. (and more...)
# - email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/13. (and more...)
# - email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/14. (and more...)
# - email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/15. (and more...)
# - email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/16. (and more...)
# - email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/17. (and more...)
# - email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/18. (and more...)
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/1.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/10.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/11.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/12.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/13.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/14.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/15.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/16.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/17.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/18.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/19.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/2.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/20.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/21.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/22.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/23.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/24.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/25.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/26.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/27.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/28.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/29.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/3.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/30.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/31.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/32.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/33.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/34.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/35.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/36.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/37.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/38.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/39.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/4.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/40.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/41.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/42.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/43.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/44.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/45.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/5.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/6.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/62.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/63.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/64.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/65.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/66.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/67.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/68.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/69.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/7.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/70.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/71.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/72.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/73.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/74.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/75.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/78.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/79.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/8.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/83.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/84.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/85.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/86.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/87.
# ✅ Sent to SNS: email-sec-datasets-bronze/extracted/enron_mail_20150507/maildir/allen-p/inbox/9.
